# %% [markdown]
# # Preprocess

# %%
import sys
import os
sys.path.append('../src')

# %%
from preprocess import *

# %%
metadata_dir = os.path.join('..', 'data','metadata')
images_dir = os.path.join('..', 'data','images')
processed_dir = os.path.join('..', 'data','processed')
metadata_file = os.path.join(metadata_dir,'Data_Entry_2017_v2020.csv')

# %%
preprocess_data(metadata_file,images_dir,processed_dir,metadata_dir)
# Out:
# Negativos antes del undersampling: 42329
# Negativos después del undersampling: 15661
# Negativos antes del undersampling: 6044
# Negativos después del undersampling: 2103
# c:\Users\MEDHYCON\anaconda3\envs\models_env\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# c:\Users\MEDHYCON\anaconda3\envs\models_env\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
import pandas as pd
import os
metadata_dir = os.path.join('..', 'data','metadata')
train_csv = os.path.join(metadata_dir,'train_metadata.csv')
train_csv = pd.read_csv(train_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
train_metadata = train_csv

class_counts = train_metadata.drop(columns=["label"]).sum()

# Crear el barplot
plt.figure(figsize=(12,6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Frecuencia de Clases en el Conjunto de Train_Metadata')
plt.xlabel('Clases')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.show()
